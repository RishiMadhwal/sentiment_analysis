# %% [markdown]
# <a href="https://colab.research.google.com/github/RishiMadhwal/sentiment_analysis/blob/main/Test_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy as sp

# %%
df=pd.read_excel("/content/Sample_dataset_Reviews .xlsx",sheet_name="Training_set")

# %%
df.head()
# Out:
#     Location  Phone Number                    Reviews (Positive)  \
# 0     Mumbai    9876543210    "Amazing service and great staff!"
# 1      Delhi    8765432109      "Best place for authentic food!"
# 2  Bangalore    7654321098    "Quick response and professional."
# 3  Hyderabad    6543210987                  "Delicious biryani!"
# 4    Chennai    9432109876  "Friendly staff and great ambiance."
#
#                 Reviews (Negative)                   E-mail  \
# 0        "Extremely slow service."      info@mumbaicafe.com
# 1  "Food was cold and overpriced."   contact@delhibites.com
# 2         "Poor customer support."   support@bangaloreit.in
# 3       "Found a hair in my food."  hello@hyderabadhotel.in
# 4     "The place was too crowded."  feedback@chennaicafe.in
#
#                          Address       Business Hours
# 0      123, Marine Drive, Mumbai   9:00 AM - 11:00 PM
# 1     45, Connaught Place, Delhi  10:00 AM - 10:00 PM
# 2         78, MG Road, Bangalore    8:00 AM - 9:00 PM
# 3  55, Charminar Road, Hyderabad  11:00 AM - 12:00 AM
# 4      88, Marina Beach, Chennai   9:00 AM - 10:00 PM

# %%
df.tail()
